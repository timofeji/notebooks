# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time

# %%
SEED = 211
NUM_POINTS = 100

# Decision line we're trying to predict
t_w1, t_w2, b = 0.49671415, -0.1382643, 0.64768854

# %%
#### Generate random test data for the perceptron to train one ####

def generate_linearly_separable_data(NUM_POINTS, w1, w2, b, seed=None):
    np.random.seed(seed)

    # Generate random points
    points = np.random.randn(NUM_POINTS, 2)

    # Compute the labels for the points based on their position relative to the line
    labels = np.sign(w1 * points[:, 0] + w2 * points[:, 1] + b)

    return points, labels


def plot_linearly_separable_data(points, labels, w1, w2, b):
    plt.scatter(points[labels == 1, 0],
                points[labels == 1, 1], c='blue', label='Class 1')
    plt.scatter(points[labels == -1, 0],
                points[labels == -1, 1], c='red', label='Class -1')

    # Plot the separating line
    x1 = np.linspace(points[:, 0].min() - 1, points[:, 0].max() + 1, 100)
    x2 = -(w1 * x1 + b) / w2
    plt.plot(x1, x2, 'g--', label='Separating Line')

    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.legend()
    plt.show()


points, labels = generate_linearly_separable_data(
    NUM_POINTS, t_w1, t_w2, b, seed=SEED)
plot_linearly_separable_data(points, labels, t_w1, t_w2, b)

# %%
##### PERCEPTRON LEARNING ALGORHITM AND TRAINING #####
W = np.random.randn(2)
b = 2
lr = 0.2;

# Heaviside step function
def activation(z):
    return z >= 0


def forward(X):
    z = X*W
    return activation(z)

def plot_training():
    clear_output(wait=True)
    plt.scatter(points[labels == 1, 0],
                points[labels == 1, 1], c='blue', label='Class 1')
    plt.scatter(points[labels == -1, 0],
                points[labels == -1, 1], c='red', label='Class -1')

    X = np.linspace(points[:, 0].min() - 1, points[:, 0].max() + 1, 100)
    M = -W[0] / W[1]
    b_plot = -b / W[1]
    y_plot = M * X + b
    plt.plot(X, y_plot, 'r--', label='Decision Boundary')

    plt.title(f'Iteration {i + 1}')
    plt.legend()
    plt.show()

# Train our perceptron
for i in range(len(points)):
    y = forward(points)

    W = lr


    plot_training()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 40
#      35 x_i = points[i]
#      36 print(x_i)
# ---> 40 plot_training()
#      41 time.sleep(1)
#
# Cell In[13], line 29, in plot_training()
#      27 plt.title(f'Iteration {i + 1}')
#      28 plt.legend()
# ---> 29 plt.show()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py:421, in show(*args, **kwargs)
#     377 """
#     378 Display all open figures.
#     379
#    (...)
#     418 explicitly there.
#     419 """
#     420 _warn_if_gui_out_of_main_thread()
# --> 421 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~\AppData\Roaming\Python\Python39\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backend_bases.py:2318, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
# -> 2318         bbox_inches = self.figure.get_tightbbox(
#    2319             renderer, bbox_extra_artists=bbox_extra_artists)
#    2320         if pad_inches is None:
#    2321             pad_inches = rcParams['savefig.pad_inches']
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\figure.py:1734, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1731     artists = bbox_extra_artists
#    1733 for a in artists:
# -> 1734     bbox = a.get_tightbbox(renderer)
#    1735     if bbox is not None:
#    1736         bb.append(bbox)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py:4431, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4429         if ba:
#    4430             bb.append(ba)
# -> 4431 self._update_title_position(renderer)
#    4432 axbbox = self.get_window_extent(renderer)
#    4433 bb.append(axbbox)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py:3015, in _AxesBase._update_title_position(self, renderer)
#    3013 top = max(top, bb.ymax)
#    3014 if title.get_text():
# -> 3015     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3016     if ax.yaxis.offsetText.get_text():
#    3017         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py:1269, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1267 # take care of label
#    1268 if self.label.get_visible():
# -> 1269     bb = self.label.get_window_extent(renderer)
#    1270     # for constrained/tight_layout, we want to ignore the label's
#    1271     # width/height because the adjustments they make can't be improved.
#    1272     # this code collapses the relevant direction
#    1273     if for_layout_only:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\text.py:903, in Text.get_window_extent(self, renderer, dpi)
#     901     with cbook._setattr_cm(self.figure, dpi=dpi):
#     902         tx, ty = self._get_xy_display()
# --> 903         return Bbox.from_bounds(tx, ty, 0, 0)
#     905 if renderer is not None:
#     906     self._renderer = renderer
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\transforms.py:807, in Bbox.from_bounds(x0, y0, width, height)
#     800 @staticmethod
#     801 def from_bounds(x0, y0, width, height):
#     802     """
#     803     Create a new `Bbox` from *x0*, *y0*, *width* and *height*.
#     804
#     805     *width* and *height* may be negative.
#     806     """
# --> 807     return Bbox.from_extents(x0, y0, x0 + width, y0 + height)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\transforms.py:826, in Bbox.from_extents(minpos, *args)
#     809 @staticmethod
#     810 def from_extents(*args, minpos=None):
#     811     """
#     812     Create a new Bbox from *left*, *bottom*, *right* and *top*.
#     813
#    (...)
#     824        scales where negative bounds result in floating point errors.
#     825     """
# --> 826     bbox = Bbox(np.reshape(args, (2, 2)))
#     827     if minpos is not None:
#     828         bbox._minpos[:] = minpos
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\transforms.py:772, in Bbox.__init__(self, points, **kwargs)
#     768 self._ignore = True
#     769 # it is helpful in some contexts to know if the bbox is a
#     770 # default or has been mutated; we store the orig points to
#     771 # support the mutated methods
# --> 772 self._points_orig = self._points.copy()
#
# KeyboardInterrupt:
